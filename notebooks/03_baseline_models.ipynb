# %%
# Baseline Machine Learning Models for ADR Prediction
# This notebook trains and evaluates classical ML models as baselines

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import (
    roc_auc_score, average_precision_score, f1_score,
    classification_report, confusion_matrix, roc_curve,
    precision_recall_curve
)
from sklearn.utils.class_weight import compute_sample_weight
import json

# Set style
# Keep figures consistent across sections to make model comparisons easier.
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# =============================================================================
# 1. LOAD DATA
# =============================================================================

from pathlib import Path
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "processed_data").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
BASE_DIR = PROJECT_ROOT
DATA_DIR = BASE_DIR / "processed_data"
RESULTS_DIR = BASE_DIR / "results"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# Load pre-generated train/validation/test splits from preprocessing pipeline.
print("Loading preprocessed data...")
X_train = pd.read_csv(f"{DATA_DIR}/X_train.csv")
y_train = pd.read_csv(f"{DATA_DIR}/y_train.csv").values.ravel()
X_val = pd.read_csv(f"{DATA_DIR}/X_val.csv")
y_val = pd.read_csv(f"{DATA_DIR}/y_val.csv").values.ravel()
X_test = pd.read_csv(f"{DATA_DIR}/X_test.csv")
y_test = pd.read_csv(f"{DATA_DIR}/y_test.csv").values.ravel()

# Basic schema checks to catch split/load issues early.
# Ensures all models train on consistent numeric feature matrices.
expected_columns = X_train.columns.tolist()
if X_val.columns.tolist() != expected_columns or X_test.columns.tolist() != expected_columns:
    raise ValueError("Feature columns are not consistent across train/val/test splits")

non_numeric_cols = [c for c in expected_columns if not pd.api.types.is_numeric_dtype(X_train[c])]
if non_numeric_cols:
    raise TypeError(f"Non-numeric features found: {non_numeric_cols}")

if X_train.isnull().any().any() or X_val.isnull().any().any() or X_test.isnull().any().any():
    raise ValueError("Missing values found in one or more feature splits")

print(f"Train: {X_train.shape}, Val: {X_val.shape}, Test: {X_test.shape}")
print(f"ADR rate - Train: {y_train.mean():.3f}, Val: {y_val.mean():.3f}, Test: {y_test.mean():.3f}")
print(f"Results directory: {RESULTS_DIR}")

# =============================================================================
# 2. TRAIN BASELINE MODELS
# =============================================================================

# Calculate class imbalance ratio (negative/positive) for weighting heuristics.
class_weight = {0: 1.0, 1: (y_train == 0).sum() / (y_train == 1).sum()}
print(f"\nClass weight: {class_weight}")

# Define baseline classifiers with conservative defaults for first-pass benchmarking.
models = {
    'Logistic Regression': LogisticRegression(
        max_iter=1000,
        class_weight='balanced',
        random_state=42,
        n_jobs=-1
    ),
    'Random Forest': RandomForestClassifier(
        n_estimators=100,
        max_depth=20,
        class_weight='balanced',
        random_state=42,
        n_jobs=-1
    ),
    'Gradient Boosting': GradientBoostingClassifier(
        n_estimators=100,
        max_depth=5,
        learning_rate=0.1,
        random_state=42
    ),
    'XGBoost': XGBClassifier(
        n_estimators=100,
        max_depth=7,
        learning_rate=0.1,
        scale_pos_weight=class_weight[1],
        random_state=42,
        n_jobs=-1,
        eval_metric='logloss'
    )
}

# Train and evaluate each baseline using the same split for fair comparison.
results = {}

for name, model in models.items():
    print(f"\nTraining {name}...")
    
    # Train
    if name == 'Gradient Boosting':
        gb_sample_weight = compute_sample_weight(class_weight='balanced', y=y_train)
        model.fit(X_train, y_train, sample_weight=gb_sample_weight)
    else:
        model.fit(X_train, y_train)
    
    # Predict probabilities for threshold-free metrics and later threshold tuning.
    y_val_proba = model.predict_proba(X_val)[:, 1]
    y_test_proba = model.predict_proba(X_test)[:, 1]
    
    # Calculate metrics
    val_auroc = roc_auc_score(y_val, y_val_proba)
    val_auprc = average_precision_score(y_val, y_val_proba)
    test_auroc = roc_auc_score(y_test, y_test_proba)
    test_auprc = average_precision_score(y_test, y_test_proba)
    
    # Store results
    results[name] = {
        'model': model,
        'val_auroc': val_auroc,
        'val_auprc': val_auprc,
        'test_auroc': test_auroc,
        'test_auprc': test_auprc,
        'y_val_proba': y_val_proba,
        'y_test_proba': y_test_proba
    }
    
    print(f"Val AUROC: {val_auroc:.4f}, Val AUPRC: {val_auprc:.4f}")
    print(f"Test AUROC: {test_auroc:.4f}, Test AUPRC: {test_auprc:.4f}")

# =============================================================================
# 3. RESULTS SUMMARY
# =============================================================================

print("\n" + "="*80)
print("BASELINE MODELS SUMMARY")
print("="*80)

results_df = pd.DataFrame({
    'Model': list(results.keys()),
    'Val AUROC': [v['val_auroc'] for v in results.values()],
    'Val AUPRC': [v['val_auprc'] for v in results.values()],
    'Test AUROC': [v['test_auroc'] for v in results.values()],
    'Test AUPRC': [v['test_auprc'] for v in results.values()]
})

print("\n", results_df.to_string(index=False))

# Save machine-readable summary artifacts for reproducible reporting.
results_df.to_csv(RESULTS_DIR / "baseline_models_metrics.csv", index=False)

results_payload = {
    model_name: {
        'val_auroc': float(metrics['val_auroc']),
        'val_auprc': float(metrics['val_auprc']),
        'test_auroc': float(metrics['test_auroc']),
        'test_auprc': float(metrics['test_auprc'])
    }
    for model_name, metrics in results.items()
}

with open(RESULTS_DIR / "baseline_models_metrics.json", "w") as f:
    json.dump(results_payload, f, indent=2)

print("Saved baseline metrics to CSV and JSON")

# =============================================================================
# 4. VISUALIZATIONS
# =============================================================================

# ROC Curves: discrimination quality across all classification thresholds.
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
for name, metrics in results.items():
    fpr, tpr, _ = roc_curve(y_test, metrics['y_test_proba'])
    plt.plot(fpr, tpr, label=f"{name} (AUC={metrics['test_auroc']:.3f})", linewidth=2)

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves - Baseline Models')
plt.legend()
plt.grid(alpha=0.3)

# PR Curves: precision/recall tradeoff, especially informative for ADR imbalance.
plt.subplot(1, 2, 2)
for name, metrics in results.items():
    precision, recall, _ = precision_recall_curve(y_test, metrics['y_test_proba'])
    plt.plot(recall, precision, label=f"{name} (AUPRC={metrics['test_auprc']:.3f})", linewidth=2)

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves - Baseline Models')
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(RESULTS_DIR / "baseline_models_comparison.png", dpi=300, bbox_inches='tight')
plt.show()

# =============================================================================
# 5. BEST MODEL ANALYSIS
# =============================================================================

# Pick best model by validation AUROC (avoids selecting by test performance).
best_model_name = max(results.items(), key=lambda x: x[1]['val_auroc'])[0]
best_model_results = results[best_model_name]

# Tune decision threshold on validation data, then apply once to held-out test data.
threshold_grid = np.linspace(0.05, 0.95, 19)
val_f1_scores = [
    f1_score(y_val, (best_model_results['y_val_proba'] >= t).astype(int))
    for t in threshold_grid
]
best_threshold = float(threshold_grid[int(np.argmax(val_f1_scores))])

print(f"\n{'='*80}")
print(f"BEST MODEL: {best_model_name}")
print(f"{'='*80}")

# Predictions at tuned threshold
y_test_pred = (best_model_results['y_test_proba'] >= best_threshold).astype(int)
print(f"Selected threshold from validation (max F1): {best_threshold:.2f}")

# Classification report at the tuned threshold.
best_model_report = classification_report(
    y_test,
    y_test_pred,
    target_names=['No ADR', 'ADR'],
    output_dict=True
)
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred, target_names=['No ADR', 'ADR']))

# Save per-row predictions and structured report payloads for downstream analysis.
best_predictions_df = pd.DataFrame({
    'y_true': y_test,
    'y_proba': best_model_results['y_test_proba'],
    'y_pred_tuned': y_test_pred
})
best_predictions_df.to_csv(RESULTS_DIR / "best_baseline_test_predictions.csv", index=False)

threshold_tuning_df = pd.DataFrame({
    'threshold': threshold_grid,
    'val_f1': val_f1_scores
})
threshold_tuning_df.to_csv(RESULTS_DIR / "best_baseline_threshold_tuning.csv", index=False)

with open(RESULTS_DIR / "best_baseline_classification_report.json", "w") as f:
    json.dump({
        'best_model': best_model_name,
        'selection_metric': 'val_auroc',
        'selected_threshold': best_threshold,
        'report': best_model_report
    }, f, indent=2)

# Confusion matrix for tuned-threshold test predictions.
cm = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['No ADR', 'ADR'],
            yticklabels=['No ADR', 'ADR'])
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title(f'Confusion Matrix - {best_model_name}')
plt.savefig(RESULTS_DIR / "best_baseline_confusion_matrix.png", dpi=300, bbox_inches='tight')
plt.show()

# Tree-model feature importances (top 10) when estimator exposes them.
if hasattr(best_model_results['model'], 'feature_importances_'):
    feature_names = X_train.columns
    importances = best_model_results['model'].feature_importances_
    indices = np.argsort(importances)[::-1][:10]
    
    plt.figure(figsize=(10, 6))
    plt.bar(range(10), importances[indices])
    plt.xticks(range(10), [feature_names[i] for i in indices], rotation=45, ha='right')
    plt.xlabel('Features')
    plt.ylabel('Importance')
    plt.title(f'Top 10 Feature Importances - {best_model_name}')
    plt.tight_layout()
    feature_importance_df = pd.DataFrame({
        'feature': [feature_names[i] for i in indices],
        'importance': importances[indices]
    })
    feature_importance_df.to_csv(RESULTS_DIR / "feature_importance_top10.csv", index=False)
    
    plt.savefig(RESULTS_DIR / "feature_importance.png", dpi=300, bbox_inches='tight')
    plt.show()

print("\n" + "="*80)
print("Baseline model evaluation complete!")
print("="*80)
# Out:
# Patients: (299712, 6)
# Prescriptions (sample): (200000, 21)
# Diagnoses (sample): (200000, 5)
# /var/folders/d3/3q6sgkhd6q59z7zwcpyxppdm0000gn/T/ipykernel_69614/2322416862.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   prescriptions = pd.read_csv(
