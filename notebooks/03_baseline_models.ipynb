# %%
"""
Baseline Machine Learning Models for ADR Prediction

Trains four classical ML models (Logistic Regression, Random Forest,
Gradient Boosting, XGBoost) on the min1000 12-feature dataset.
Uses a 500k-row subsample of the training set to avoid memory issues.
Evaluates on the full test set at thresholds 0.3, 0.5, and 0.7.
Saves models and metrics to results/baseline/.
"""

import json
import pickle
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    average_precision_score, confusion_matrix, f1_score,
    precision_recall_curve, roc_auc_score, roc_curve,
)
from sklearn.utils.class_weight import compute_sample_weight
from xgboost import XGBClassifier

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

RANDOM_STATE = 42
SAMPLE_N = 500_000

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "processed_data_min1000_private").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

DATA_DIR    = PROJECT_ROOT / "processed_data_min1000_private"
RESULTS_DIR = PROJECT_ROOT / "results" / "baseline"
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# =============================================================================
# 1. LOAD DATA
# =============================================================================
print("Loading data...")
X_train_full = pd.read_csv(DATA_DIR / "X_train.csv")
y_train_full = pd.read_csv(DATA_DIR / "y_train.csv").values.ravel()
X_test       = pd.read_csv(DATA_DIR / "X_test.csv")
y_test       = pd.read_csv(DATA_DIR / "y_test.csv").values.ravel()

# Subsample training set to avoid OOM on tree models
rng = np.random.default_rng(RANDOM_STATE)
idx = rng.choice(len(X_train_full), size=min(SAMPLE_N, len(X_train_full)), replace=False)
X_train = X_train_full.iloc[idx].reset_index(drop=True)
y_train = y_train_full[idx]

print(f"Train sample: {X_train.shape}  Test: {X_test.shape}")
print(f"ADR rate — train sample: {y_train.mean():.3f}  test: {y_test.mean():.3f}")

# =============================================================================
# 2. TRAIN BASELINE MODELS
# =============================================================================
class_weight_ratio = float((y_train == 0).sum() / (y_train == 1).sum())

models = {
    "logistic_regression": LogisticRegression(
        max_iter=1000, class_weight="balanced",
        random_state=RANDOM_STATE, n_jobs=-1,
    ),
    "random_forest": RandomForestClassifier(
        n_estimators=100, max_depth=20, class_weight="balanced",
        random_state=RANDOM_STATE, n_jobs=-1,
    ),
    "gradient_boosting": GradientBoostingClassifier(
        n_estimators=100, max_depth=5, learning_rate=0.1,
        random_state=RANDOM_STATE,
    ),
    "xgboost": XGBClassifier(
        n_estimators=100, max_depth=7, learning_rate=0.1,
        scale_pos_weight=class_weight_ratio,
        random_state=RANDOM_STATE, n_jobs=-1, eval_metric="logloss",
    ),
}

results = {}

for name, model in models.items():
    print(f"\nTraining {name}...")
    if name == "gradient_boosting":
        model.fit(X_train, y_train,
                  sample_weight=compute_sample_weight("balanced", y_train))
    else:
        model.fit(X_train, y_train)

    y_proba = model.predict_proba(X_test)[:, 1]
    auroc = roc_auc_score(y_test, y_proba)
    auprc = average_precision_score(y_test, y_proba)

    threshold_metrics = {}
    for thresh in [0.3, 0.5, 0.7]:
        y_pred = (y_proba >= thresh).astype(int)
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
        threshold_metrics[str(thresh)] = {
            "sensitivity": float(tp / (tp + fn)) if (tp + fn) > 0 else 0.0,
            "specificity": float(tn / (tn + fp)) if (tn + fp) > 0 else 0.0,
            "precision":   float(tp / (tp + fp)) if (tp + fp) > 0 else 0.0,
            "f1":          float(f1_score(y_test, y_pred)),
        }

    results[name] = {
        "model":             model,
        "auroc":             float(auroc),
        "auprc":             float(auprc),
        "y_proba":           y_proba,
        "threshold_metrics": threshold_metrics,
    }
    t = threshold_metrics["0.5"]
    print(f"  AUROC={auroc:.4f}  AUPRC={auprc:.4f}  "
          f"Sens@0.5={t['sensitivity']:.4f}  Spec@0.5={t['specificity']:.4f}  "
          f"F1@0.5={t['f1']:.4f}")

# =============================================================================
# 3. SAVE MODELS AND METRICS
# =============================================================================
for name, r in results.items():
    with open(RESULTS_DIR / f"{name}.pkl", "wb") as f:
        pickle.dump(r["model"], f)

summary = {
    name: {"auroc": r["auroc"], "auprc": r["auprc"],
           "threshold_metrics": r["threshold_metrics"]}
    for name, r in results.items()
}
with open(RESULTS_DIR / "baseline_metrics.json", "w") as f:
    json.dump(summary, f, indent=2)

print(f"\nModels and metrics saved to {RESULTS_DIR}")

# =============================================================================
# 4. VISUALIZATIONS
# =============================================================================
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for name, r in results.items():
    fpr, tpr, _ = roc_curve(y_test, r["y_proba"])
    axes[0].plot(fpr, tpr, label=f"{name} (AUC={r['auroc']:.3f})", linewidth=2)

axes[0].plot([0, 1], [0, 1], "k--")
axes[0].set_xlabel("False Positive Rate")
axes[0].set_ylabel("True Positive Rate")
axes[0].set_title("ROC Curves — Baseline Models")
axes[0].legend(fontsize=9)
axes[0].grid(alpha=0.3)

for name, r in results.items():
    precision, recall, _ = precision_recall_curve(y_test, r["y_proba"])
    axes[1].plot(recall, precision, label=f"{name} (AUPRC={r['auprc']:.3f})", linewidth=2)

axes[1].set_xlabel("Recall")
axes[1].set_ylabel("Precision")
axes[1].set_title("Precision-Recall Curves — Baseline Models")
axes[1].legend(fontsize=9)
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig(RESULTS_DIR / "baseline_roc_pr_curves.png", dpi=300, bbox_inches="tight")
plt.show()

# Threshold comparison table
print("\nMetrics at threshold=0.5:")
rows = []
for name, r in results.items():
    t = r["threshold_metrics"]["0.5"]
    rows.append({"Model": name, "AUROC": r["auroc"], "AUPRC": r["auprc"],
                 "Sensitivity": t["sensitivity"], "Specificity": t["specificity"],
                 "Precision": t["precision"], "F1": t["f1"]})
display(pd.DataFrame(rows).set_index("Model").round(4))
